# %% [markdown]
# <a href="https://colab.research.google.com/github/Sejalkose/Roller_coaster/blob/main/Roller_coaster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#rollercoaster
print("welcome to roller coaster")
height = int(input("enter your height in cm: "))
if(height > 120):
  print("you can ride")
  age = int(input("enter your age: "))
  if(age < 12):
    bill = 5
    print("please pay 5$ for ticket")
  elif(age >= 12 and age <= 18):
    bill = 7
    print("please pay 7$ for ticket")
  else:
    bill = 12
    print("please pay 12$")

  want_photo =input("do you want photos? Y or N:")
  if want_photo == "Y":
    print("please pay 5$ for ticket")
    bill += 5
    print(f"your total bill is {bill}")
  else:
    print(bill)
else:
  print("gow little taller")
# Out:
# welcome to roller coaster
# enter your height in cm: 155
# you can ride
# enter your age: 23
# please pay 12$
# do you want photos? Y or N:Y
# please pay 5$ for ticket
# your total bill is 17
